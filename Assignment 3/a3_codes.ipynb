# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Combine two datasets
csvlist = ['daily_1.csv', 'daily_2.csv']
for inputfile in csvlist:
    f = open(inputfile)
    df_c = pd.read_csv(f)
    df_c.to_csv('daily_return.csv', mode='a', index=False)

# %%
# Monthly return
df = pd.read_csv('monthly.csv')
df1 = df[(df['Indexcd']==300)]
df2 = df[(df['Indexcd']=='399006')]

# csi = np.array(df1['Idxtrd08'])
# csi_list = csi.tolist()
print(pd.Series(df1['Idxrtn']).skew())
print(pd.Series(df1['Idxrtn']).kurt())
sns.displot(df1['Idxrtn'], kde = True, bins = 20,rug = True)
# Out:
# -0.2181882538505979
# 1.8065088330186643
